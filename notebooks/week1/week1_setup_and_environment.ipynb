# %% [markdown]
# <a href="https://colab.research.google.com/github/Joey-Jireh/eye-of-ra/blob/main/notebooks/week1/week1_setup_and_environment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# EYE OF RA — Environment Setup
# Run this cell once at the start of every Colab session
# It installs all the libraries we need for the entire project
# ============================================================

# Install all required libraries
# (Colab resets installations each session, so we always run this first)
# !pip install -q xgboost shap streamlit pdfplumber camelot-py[cv] \
    plotly openpyxl geopandas folium streamlit-folium

# ============================================================
# Import all libraries — this confirms everything installed correctly
# ============================================================

# Data handling
import pandas as pd          # for working with tables of data
import numpy as np           # for numerical calculations

# Machine learning
from sklearn.model_selection import train_test_split  # splits data into train/test
from sklearn.preprocessing import StandardScaler      # normalizes our numbers
from sklearn.ensemble import IsolationForest          # anomaly detection model
from sklearn.metrics import classification_report     # model evaluation
import xgboost as xgb        # our main fraud detection model

# Explainability
import shap                  # turns model outputs into plain English

# Data extraction from PDFs
import pdfplumber            # reads text and tables from PDF files

# Visualization
import matplotlib.pyplot as plt   # basic charts
import seaborn as sns             # nicer looking charts
import plotly.express as px       # interactive charts for dashboard

# System
import os                    # for file and folder operations
import warnings
warnings.filterwarnings('ignore')  # keeps output clean

# ============================================================
# Confirmation message
# ============================================================
print("=" * 50)
print("✅ Eye of Ra environment is ready")
print("=" * 50)
print(f"pandas version:    {pd.__version__}")
print(f"numpy version:     {np.__version__}")
print(f"xgboost version:   {xgb.__version__}")
print(f"shap version:      {shap.__version__}")
print("=" * 50)
print("All systems go. Let's catch some corruption. 🇬🇭")
print("=" * 50)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 5.2 MB/s eta 0:00:00
# WARNING: camelot-py 1.0.9 does not provide the extra 'cv'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 54.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 111.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.5/530.5 kB 32.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 101.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 96.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.2 MB/s eta 0:00:00
# ...
# ✅ Eye of Ra environment is ready
# ...
# pandas version:    2.2.2
# numpy version:     2.0.2
# xgboost version:   3.2.0
# ...
